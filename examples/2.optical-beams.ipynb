# %% [markdown]
# # Utilização básica do construtor de feixes

# %%
# módulo de controle simples de arrays
import numpy as np
# módulo de produção de gráficos
import matplotlib.pyplot as plt

# construção da janela computacional
l = np.linspace(-40.0, +40.0, 500); # lista de pontos da partição dos eixos x e y
X, Y = np.meshgrid(l,l);            # matriz de x e y dos pontos da malha de partição

# computação dos limites dos eixos
extremos = [
    l[0], l[-1],                    # extremos do eixo x
    l[0], l[-1]                     # extremos do eixo y
];

# %% [markdown]
# Ademais à criação de campos ópticos genéricos podemos construir diretamente feixes ópticos pelos construtores do módulo `beam`.

# %%
# retornar ao diretório raíz do projeto
# %cd -q ../
# importa o módulo beam do módulo optical
from opticalField import beam
# importa as funções intensity e phase do módulo opticalField.properties
from opticalField.properties import intensity, phase

# %% [markdown]
# ## Construção de feixe gaussiano por `beam.Gaussian`

# %% [markdown]
# A construção de um feixe gaussiano foi implementada pelo construtor `beam.Gaussian()` onde a envoltória de onda não é passada como argumento (sendo substituida pelo parâmetro `w0` que corresponde à cintura do feixe).

# %%
gaussianBeam = beam.Gaussian(
    w0 = 10.0,
    region = (X, Y)
);

# %% [markdown]
# ### Perfil de intensidade transversal do feixe gaussiano

# %%
# criação de figuras para plotagem de imagem
fig, ax = plt.subplots();

# rotulação do título da figura
ax.set_title('Intensidade');

# rotulação dos eixos coordenados
ax.set_xlabel('x($\mu$m)')
ax.set_ylabel('y($\mu$m)')

# geração de imagem do perfil de intesidade do feixe gaussiano
imageIntensity = ax.imshow(
    intensity(gaussianBeam),
    cmap = 'inferno',               # define o mapa de cores
    extent = extremos               # define a extensão dos eixos x e y
);
fig.colorbar(imageIntensity);       # insere uma colorbar

# %% [markdown]
# ### Perfil de fase transversal do feixe gaussiano

# %%
# criação de figuras para plotagem de imagem
fig, ax = plt.subplots();

# rotulação do título da figura
ax.set_title('Fase');

# rotulação dos eixos coordenados
ax.set_xlabel('x($\mu$m)')
ax.set_ylabel('y($\mu$m)')

# geração de imagem do perfil de fase do feixe gaussiano
imageIntensity = ax.imshow(
    phase(gaussianBeam),
    cmap = 'cividis',               # define o mapa de cores
    extent = extremos               # define a extensão dos eixos x e y
);
fig.colorbar(imageIntensity);       # insere uma colorbar

# %% [markdown]
# ## Construção de feixe Hermite-Gauss por `beam.HermiteGauss`

# %% [markdown]
# A construção de um feixe hermite-gauss de índices $(l,m)$ foi implementada pelo construtor `beam.HermiteGauss()` onde a envoltória de onda não é passada como argumento (sendo substituida pelos parâmetros `w0` que corresponde à cintura do feixe e à `2-tupla` de índices `index`).

# %%
hermitegaussBeam = beam.HermiteGauss(
    index = (0, 2),
    w0 = 10.0,
    region = (X, Y)
);

# %% [markdown]
# ### Perfil de intesidade transversal do feixe hermite-gauss

# %%
# criação de figuras para plotagem de imagem
fig, ax = plt.subplots();

# rotulação do título da figura
ax.set_title('Intensidade');

# rotulação dos eixos coordenados
ax.set_xlabel('x($\mu$m)')
ax.set_ylabel('y($\mu$m)')

# geração de imagem do perfil de intesidade do feixe hermite-gauss
imageIntensity = ax.imshow(
    intensity(hermitegaussBeam),
    cmap = 'inferno',               # define o mapa de cores
    extent = extremos               # define a extensão dos eixos x e y
);
fig.colorbar(imageIntensity);       # insere uma colorbar

# %% [markdown]
# ### Perfil de fase transversal do feixe hermite-gauss

# %%
# criação de figuras para plotagem de imagem
fig, ax = plt.subplots();

# rotulação do título da figura
ax.set_title('Fase');

# rotulação dos eixos coordenados
ax.set_xlabel('x($\mu$m)')
ax.set_ylabel('y($\mu$m)')

# geração de imagem do perfil de fase do feixe hermite-gauss
imageIntensity = ax.imshow(
    phase(hermitegaussBeam),
    cmap = 'cividis',               # define o mapa de cores
    extent = extremos               # define a extensão dos eixos x e y
);
fig.colorbar(imageIntensity);       # insere uma colorbar

# %% [markdown]
# ## Construção de feixes Laguerre-Gauss por `beam.LaguerreGauss`

# %% [markdown]
# A construção de um feixe laguerre-gauss de índices $(l,m)$ foi implementada pelo construtor `beam.LaguerreGauss()` onde a envoltória de onda não é passada como argumento (sendo substituida pelos parâmetros `w0` que corresponde à cintura do feixe e à `2-tupla` de índices `index`).

# %%
laguerregaussBeam = beam.LaguerreGauss(
    index = (3, 2),
    w0 = 10.0,
    region = (X, Y)
);

# %% [markdown]
# ### Perfil de intensidade transversal do feixe laguerre-gauss

# %%
# criação de figuras para plotagem de imagem
fig, ax = plt.subplots();

# rotulação do título da figura
ax.set_title('Intensidade');

# rotulação dos eixos coordenados
ax.set_xlabel('x($\mu$m)')
ax.set_ylabel('y($\mu$m)')

# geração de imagem do perfil de intesidade do feixe laguerre-gauss
imageIntensity = ax.imshow(
    intensity(laguerregaussBeam),
    cmap = 'inferno',               # define o mapa de cores
    extent = extremos               # define a extensão dos eixos x e y
);
fig.colorbar(imageIntensity);       # insere uma colorbar

# %% [markdown]
# ### Perfil de fase transversal do feixe laguerre-gauss

# %%
# criação de figuras para plotagem de imagem
fig, ax = plt.subplots();

# rotulação do título da figura
ax.set_title('Fase');

# rotulação dos eixos coordenados
ax.set_xlabel('x($\mu$m)')
ax.set_ylabel('y($\mu$m)')

# geração de imagem do perfil de fase do feixe laguerre-gauss
imageIntensity = ax.imshow(
    phase(laguerregaussBeam),
    cmap = 'cividis',               # define o mapa de cores
    extent = extremos               # define a extensão dos eixos x e y
);
fig.colorbar(imageIntensity);       # insere uma colorbar

# %% [markdown]
# ## Construção de feixes Laguerre-Gauss por `beam.Bessel`

# %% [markdown]
# A construção de um feixe bessel de índice $m$ e parâmetro $k_t$ foi implementada pelo construtor `beam.Bessel()` onde a envoltória de onda não é passada como argumento (sendo substituida pelos parâmetros `m` que corresponde ao índice $m$ e `k_t` que corresponde ao parâmetro $k_t$ do feixe).

# %%
besselBeam = beam.Bessel(
    m = 2,
    k_t = 1.0,
    region = (X, Y)
);

# %% [markdown]
# ### Perfil de intensidade transversal do feixe bessel

# %%
# criação de figuras para plotagem de imagem
fig, ax = plt.subplots();

# rotulação do título da figura
ax.set_title('Intensidade');

# rotulação dos eixos coordenados
ax.set_xlabel('x($\mu$m)')
ax.set_ylabel('y($\mu$m)')

# geração de imagem do perfil de intesidade do feixe bessel
imageIntensity = ax.imshow(
    intensity(besselBeam),
    cmap = 'inferno',               # define o mapa de cores
    extent = extremos               # define a extensão dos eixos x e y
);
fig.colorbar(imageIntensity);       # insere uma colorbar

# %% [markdown]
# ### Perfil de fase transversal do feixe bessel

# %%
# criação de figuras para plotagem de imagem
fig, ax = plt.subplots();

# rotulação do título da figura
ax.set_title('Fase');

# rotulação dos eixos coordenados
ax.set_xlabel('x($\mu$m)')
ax.set_ylabel('y($\mu$m)')

# geração de imagem do perfil de fase do feixe bessel
imageIntensity = ax.imshow(
    phase(besselBeam),
    cmap = 'cividis',               # define o mapa de cores
    extent = extremos               # define a extensão dos eixos x e y
);
fig.colorbar(imageIntensity);       # insere uma colorbar
